# %%
import pandas as pd
import numpy as np

print("Libraries Imported Successfully!")
# Out:
# Libraries Imported Successfully!

# %%
df = pd.read_csv(
    "../data/raw/skill_builder_data.csv",
    encoding="latin1",
    low_memory=False
)

print("Dataset Loaded Successfully!")
print("Shape:", df.shape)
# Out:
# Dataset Loaded Successfully!
# Shape: (525534, 30)

# %%
missing = pd.DataFrame({
    "Missing Values": df.isnull().sum(),
    "Percentage": round((df.isnull().sum()/len(df))*100,2)
})

missing.sort_values(by="Missing Values", ascending=False)
# Out:
#                       Missing Values  Percentage
# answer_id                     476856       90.74
# bottom_hint                   445627       84.80
# answer_text                    94784       18.04
# skill_name                     78690       14.97
# opportunity_original           76314       14.52
# skill_id                       66326       12.62
# correct                            0        0.00
# attempt_count                      0        0.00
# order_id                           0        0.00
# assignment_id                      0        0.00
# user_id                            0        0.00
# assistment_id                      0        0.00
# problem_id                         0        0.00
# original                           0        0.00
# position                           0        0.00
# student_class_id                   0        0.00
# sequence_id                        0        0.00
# answer_type                        0        0.00
# tutor_mode                         0        0.00
# ms_first_response                  0        0.00
# base_sequence_id                   0        0.00
# type                               0        0.00
# hint_total                         0        0.00
# hint_count                         0        0.00
# school_id                          0        0.00
# teacher_id                         0        0.00
# overlap_time                       0        0.00
# template_id                        0        0.00
# first_action                       0        0.00
# opportunity                        0        0.00

# %%
drop_columns = [
    "answer_id",
    "answer_text",
    "bottom_hint",
    "opportunity_original"
]

df.drop(columns=drop_columns, inplace=True)

print("Remaining Columns:", df.shape[1])
# Out:
# Remaining Columns: 26

# %%
df["skill_name"] = df["skill_name"].fillna("Unknown Skill")

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# skill_id             66326
# order_id                 0
# user_id                  0
# assistment_id            0
# problem_id               0
# original                 0
# correct                  0
# attempt_count            0
# ms_first_response        0
# assignment_id            0
# tutor_mode               0
# answer_type              0
# student_class_id         0
# sequence_id              0
# position                 0
# type                     0
# base_sequence_id         0
# skill_name               0
# teacher_id               0
# school_id                0
# hint_count               0
# hint_total               0
# overlap_time             0
# template_id              0
# first_action             0
# opportunity              0
# dtype: int64

# %%
print("Duplicate Rows Before:", df.duplicated().sum())
# Out:
# Duplicate Rows Before: 0

# %%
df.drop_duplicates(inplace=True)

print("Duplicate Rows After:", df.duplicated().sum())
# Out:
# Duplicate Rows After: 0

# %%
df.dtypes
# Out:
# order_id               int64
# assignment_id          int64
# user_id                int64
# assistment_id          int64
# problem_id             int64
# original               int64
# correct                int64
# attempt_count          int64
# ms_first_response      int64
# tutor_mode            object
# answer_type           object
# sequence_id            int64
# student_class_id       int64
# position               int64
# type                  object
# base_sequence_id       int64
# skill_id             float64
# skill_name            object
# teacher_id             int64
# school_id              int64
# hint_count             int64
# hint_total             int64
# overlap_time           int64
# template_id            int64
# first_action           int64
# opportunity            int64
# dtype: object

# %%
numerical_columns = df.select_dtypes(include=["int64", "float64"]).columns.tolist()
categorical_columns = df.select_dtypes(include=["object"]).columns.tolist()

print("Numerical Columns")
print(numerical_columns)

print("\nCategorical Columns")
print(categorical_columns)
# Out:
# Numerical Columns
# ['order_id', 'assignment_id', 'user_id', 'assistment_id', 'problem_id', 'original', 'correct', 'attempt_count', 'ms_first_response', 'sequence_id', 'student_class_id', 'position', 'base_sequence_id', 'skill_id', 'teacher_id', 'school_id', 'hint_count', 'hint_total', 'overlap_time', 'template_id', 'first_action', 'opportunity']
#
# Categorical Columns
# ['tutor_mode', 'answer_type', 'type', 'skill_name']

# %%
print("Rows :", df.shape[0])
print("Columns :", df.shape[1])
# Out:
# Rows : 525534
# Columns : 26

# %%
df.to_csv(
    "../data/processed/cleaned_skill_builder.csv",
    index=False
)

print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!

# %%
print("="*60)
print("DATA CLEANING & PREPROCESSING COMPLETED")
print("="*60)

print(f"Rows                : {df.shape[0]}")
print(f"Columns             : {df.shape[1]}")
print(f"Missing Values      : {df.isnull().sum().sum()}")
print(f"Duplicate Records   : {df.duplicated().sum()}")

print("="*60)
# Out:
# ============================================================
# DATA CLEANING & PREPROCESSING COMPLETED
# ============================================================
# Rows                : 525534
# Columns             : 26
# Missing Values      : 66326
# Duplicate Records   : 0
# ============================================================
